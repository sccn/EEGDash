# %% [markdown]
# Tests showing BIDSDataset not able to handle example EEGLAB dataset and slower than pybids

# %%
from braindecode.datasets import BIDSDataset
from bids import BIDSLayout

# %%
bids = BIDSDataset(root="/mnt/nemar/openneuro/ds003645", preload=False)
# Can't import regular EEGLAB dataset
# Out:
# CPU times: user 2 μs, sys: 1e+03 ns, total: 3 μs
# Wall time: 4.05 μs
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 get_ipython().run_line_magic('time', '')
# ----> 2 bids = BIDSDataset(root='/mnt/nemar/openneuro/ds003645', preload=False)
#
# File <string>:20, in __init__(self, root, subjects, sessions, tasks, acquisitions, runs, processings, recordings, spaces, splits, descriptions, suffixes, extensions, datatypes, check, preload, n_jobs)
#
# File ~/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:183, in BIDSDataset.__post_init__(self)
#     176 if self._filter_out_epochs:
#     177     bids_paths = [
#     178         bids_path
#     179         for bids_path in bids_paths
#     180         if not (bids_path.suffix == "epo" and bids_path.extension == ".fif")
#     181     ]
# --> 183 all_base_ds = Parallel(n_jobs=self.n_jobs)(
#     184     delayed(self._get_dataset)(bids_path) for bids_path in bids_paths
#     185 )
#     186 super().__init__(all_base_ds)
#
# File ~/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/joblib/parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File ~/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/joblib/parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File ~/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190, in BIDSDataset._get_dataset(self, bids_path)
#     188 def _get_dataset(self, bids_path: mne_bids.BIDSPath) -> BaseDataset:
#     189     description = _descriptiion_from_bids_path(bids_path)
# --> 190     raw = mne_bids.read_raw_bids(bids_path, verbose=False)
#     191     if self.preload:
#     192         raw.load_data()
#
# File <decorator-gen-392>:10, in read_raw_bids(bids_path, extra_params, verbose)
#
# File ~/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/mne_bids/read.py:905, in read_raw_bids(bids_path, extra_params, verbose)
#     903 if raw_path.suffix == ".fif" and "allow_maxshield" not in extra_params:
#     904     extra_params["allow_maxshield"] = True
# --> 905 raw = _read_raw(
#     906     raw_path,
#     907     electrode=None,
#     908     hsp=None,
#     909     hpi=None,
#     910     config_path=config_path,
#     911     **extra_params,
#     912 )
#     914 # Try to find an associated events.tsv to get information about the
#     915 # events in the recorded data
#     916 if (
#     917     bids_path.subject == "emptyroom" and bids_path.task == "noise"
#     918 ) or bids_path.task.startswith("rest"):
#
# File ~/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/mne_bids/read.py:72, in _read_raw(raw_path, electrode, hsp, hpi, allow_maxshield, config_path, **kwargs)
#      70 elif ext in [".ds", ".vhdr", ".set", ".edf", ".bdf", ".EDF", ".snirf", ".cdt"]:
#      71     raw_path = Path(raw_path)
# ---> 72     raw = reader[ext](raw_path, **kwargs)
#      74 # MEF and NWB are allowed, but not yet implemented
#      75 elif ext in [".mef", ".nwb"]:
#
# File ~/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/mne/io/eeglab/eeglab.py:327, in read_raw_eeglab(input_fname, eog, preload, uint16_codec, montage_units, verbose)
#     285 @fill_doc
#     286 def read_raw_eeglab(
#     287     input_fname,
#    (...)
#     292     verbose=None,
#     293 ) -> "RawEEGLAB":
#     294     r"""Read an EEGLAB .set file.
#     295
#     296     Parameters
#    (...)
#     325     .. versionadded:: 0.11.0
#     326     """
# --> 327     return RawEEGLAB(
#     328         input_fname=input_fname,
#     329         preload=preload,
#     330         eog=eog,
#     331         uint16_codec=uint16_codec,
#     332         montage_units=montage_units,
#     333         verbose=verbose,
#     334     )
#
# File <decorator-gen-279>:12, in __init__(self, input_fname, eog, preload, uint16_codec, montage_units, verbose)
#
# File ~/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/mne/io/eeglab/eeglab.py:460, in RawEEGLAB.__init__(self, input_fname, eog, preload, uint16_codec, montage_units, verbose)
#     458 # read the data
#     459 if isinstance(eeg.data, str):
# --> 460     data_fname = _check_eeglab_fname(input_fname, eeg.data)
#     461     logger.info(f"Reading {data_fname}")
#     463     super().__init__(
#     464         info,
#     465         preload,
#    (...)
#     469         verbose=verbose,
#     470     )
#
# File ~/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/mne/io/eeglab/eeglab.py:53, in _check_eeglab_fname(fname, dataname)
#      48     raise NotImplementedError(
#      49         "Old data format .dat detected. Please update your EEGLAB "
#      50         "version and resave the data in .fdt format"
#      51     )
#      52 if fmt != ".set" and fmt != ".fdt":
# ---> 53     raise ValueError(f"The file extension must be .set or .fdt, not {fmt}")
#      54 basedir = op.dirname(fname)
#      55 data_fname = op.join(basedir, dataname)
#
# ValueError: The file extension must be .set or .fdt, not

# %%
# %time bids = BIDSDataset(root='/mnt/nemar/openneuro/ds002718', preload=False)
# Out:
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: There are channels without locations (n/a) that are not marked as bad: ['EEG061', 'EEG062', 'EEG063', 'EEG064']
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Not setting positions of 4 ecg/eog channels found in montage:
# ['EEG061', 'EEG062', 'EEG063', 'EEG064']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Unable to map the following column(s) to to MNE:
# gender: M
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: There are channels without locations (n/a) that are not marked as bad: ['EEG061', 'EEG062', 'EEG063', 'EEG064']
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Not setting positions of 4 ecg/eog channels found in montage:
# ['EEG061', 'EEG062', 'EEG063', 'EEG064']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Unable to map the following column(s) to to MNE:
# gender: M
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: There are channels without locations (n/a) that are not marked as bad: ['EEG061', 'EEG062', 'EEG063', 'EEG064']
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Not setting positions of 4 ecg/eog channels found in montage:
# ['EEG061', 'EEG062', 'EEG063', 'EEG064']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Unable to map the following column(s) to to MNE:
# gender: n/a
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: There are channels without locations (n/a) that are not marked as bad: ['EEG061', 'EEG062', 'EEG063', 'EEG064']
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Not setting positions of 4 ecg/eog channels found in montage:
# ['EEG061', 'EEG062', 'EEG063', 'EEG064']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Unable to map the following column(s) to to MNE:
# gender: M
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: There are channels without locations (n/a) that are not marked as bad: ['EEG061', 'EEG062', 'EEG063', 'EEG064']
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Not setting positions of 4 ecg/eog channels found in montage:
# ['EEG061', 'EEG062', 'EEG063', 'EEG064']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Unable to map the following column(s) to to MNE:
# gender: n/a
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Estimated head radius (11.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: There are channels without locations (n/a) that are not marked as bad: ['EEG061', 'EEG062', 'EEG063', 'EEG064']
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Not setting positions of 4 ecg/eog channels found in montage:
# ['EEG061', 'EEG062', 'EEG063', 'EEG064']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Unable to map the following column(s) to to MNE:
# gender: n/a
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: There are channels without locations (n/a) that are not marked as bad: ['EEG061', 'EEG062', 'EEG063', 'EEG064']
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Not setting positions of 4 ecg/eog channels found in montage:
# ['EEG061', 'EEG062', 'EEG063', 'EEG064']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Unable to map the following column(s) to to MNE:
# gender: F
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: There are channels without locations (n/a) that are not marked as bad: ['EEG061', 'EEG062', 'EEG063', 'EEG064']
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Not setting positions of 4 ecg/eog channels found in montage:
# ['EEG061', 'EEG062', 'EEG063', 'EEG064']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Unable to map the following column(s) to to MNE:
# gender: M
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Estimated head radius (11.0 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: There are channels without locations (n/a) that are not marked as bad: ['EEG061', 'EEG062', 'EEG063', 'EEG064']
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Not setting positions of 4 ecg/eog channels found in montage:
# ['EEG061', 'EEG062', 'EEG063', 'EEG064']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Unable to map the following column(s) to to MNE:
# gender: F
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Estimated head radius (11.0 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: There are channels without locations (n/a) that are not marked as bad: ['EEG061', 'EEG062', 'EEG063', 'EEG064']
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Not setting positions of 4 ecg/eog channels found in montage:
# ['EEG061', 'EEG062', 'EEG063', 'EEG064']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Unable to map the following column(s) to to MNE:
# gender: M
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: There are channels without locations (n/a) that are not marked as bad: ['EEG061', 'EEG062', 'EEG063', 'EEG064']
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Not setting positions of 4 ecg/eog channels found in montage:
# ['EEG061', 'EEG062', 'EEG063', 'EEG064']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Unable to map the following column(s) to to MNE:
# gender: M
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: There are channels without locations (n/a) that are not marked as bad: ['EEG061', 'EEG062', 'EEG063', 'EEG064']
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Not setting positions of 4 ecg/eog channels found in montage:
# ['EEG061', 'EEG062', 'EEG063', 'EEG064']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Unable to map the following column(s) to to MNE:
# gender: n/a
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: There are channels without locations (n/a) that are not marked as bad: ['EEG061', 'EEG062', 'EEG063', 'EEG064']
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Not setting positions of 4 ecg/eog channels found in montage:
# ['EEG061', 'EEG062', 'EEG063', 'EEG064']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Unable to map the following column(s) to to MNE:
# gender: F
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: There are channels without locations (n/a) that are not marked as bad: ['EEG061', 'EEG062', 'EEG063', 'EEG064']
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Not setting positions of 4 ecg/eog channels found in montage:
# ['EEG061', 'EEG062', 'EEG063', 'EEG064']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Unable to map the following column(s) to to MNE:
# gender: M
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: There are channels without locations (n/a) that are not marked as bad: ['EEG061', 'EEG062', 'EEG063', 'EEG064']
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Not setting positions of 4 ecg/eog channels found in montage:
# ['EEG061', 'EEG062', 'EEG063', 'EEG064']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Unable to map the following column(s) to to MNE:
# gender: F
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: There are channels without locations (n/a) that are not marked as bad: ['EEG061', 'EEG062', 'EEG063', 'EEG064']
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Not setting positions of 4 ecg/eog channels found in montage:
# ['EEG061', 'EEG062', 'EEG063', 'EEG064']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Unable to map the following column(s) to to MNE:
# gender: F
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: There are channels without locations (n/a) that are not marked as bad: ['EEG061', 'EEG062', 'EEG063', 'EEG064']
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Not setting positions of 4 ecg/eog channels found in montage:
# ['EEG061', 'EEG062', 'EEG063', 'EEG064']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Unable to map the following column(s) to to MNE:
# gender: F
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Estimated head radius (11.8 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# CPU times: user 10.8 s, sys: 11.4 s, total: 22.2 s
# Wall time: 1min 29s
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: There are channels without locations (n/a) that are not marked as bad: ['EEG061', 'EEG062', 'EEG063', 'EEG064']
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Not setting positions of 4 ecg/eog channels found in montage:
# ['EEG061', 'EEG062', 'EEG063', 'EEG064']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)
# /home/dung/Documents/EEG-Dash-Data/.venv/lib/python3.10/site-packages/braindecode/datasets/bids.py:190: RuntimeWarning: Unable to map the following column(s) to to MNE:
# gender: n/a
#   raw = mne_bids.read_raw_bids(bids_path, verbose=False)

# %%
# %time layout = BIDSLayout('/mnt/nemar/openneuro/ds003645')
# %time layout = BIDSLayout('/mnt/nemar/openneuro/ds002718')
# Out:
# CPU times: user 1.37 s, sys: 33.1 ms, total: 1.41 s
# Wall time: 1.56 s
# CPU times: user 310 ms, sys: 12.8 ms, total: 323 ms
# Wall time: 703 ms

# %% [markdown]
# Tests showing pybids utilities as well as limitations
#
# - Recording files can be retrieved fast
# - File path can be mapped to BIDS file using simple additional parsing
# - Needed info such as duration and channel count can be retrieved easily
# - Not all file level metadata files can be retrieved even though they exist
# - Top level json associated with a file can't be retrieved from file level

# %%
def get_recordings(layout: BIDSLayout):
    extensions = {
        ".set": [".set", ".fdt"],  # eeglab
        ".edf": [".edf"],  # european
        ".vhdr": [".eeg", ".vhdr", ".vmrk", ".dat", ".raw"],  # brainvision
        ".bdf": [".bdf"],  # biosemi
    }
    files = []
    for ext, exts in extensions.items():
        files = layout.get(extension=ext, return_type="filename")
        if files:
            break
    return files


print(get_recordings(BIDSLayout("/mnt/nemar/openneuro/ds002718")))
print(get_recordings(BIDSLayout("/mnt/nemar/openneuro/ds004770")))
print(get_recordings(BIDSLayout("/mnt/nemar/openneuro/ds004561")))
# Out:
# ['/mnt/nemar/openneuro/ds002718/sub-002/eeg/sub-002_task-FaceRecognition_eeg.set', '/mnt/nemar/openneuro/ds002718/sub-003/eeg/sub-003_task-FaceRecognition_eeg.set', '/mnt/nemar/openneuro/ds002718/sub-004/eeg/sub-004_task-FaceRecognition_eeg.set', '/mnt/nemar/openneuro/ds002718/sub-005/eeg/sub-005_task-FaceRecognition_eeg.set', '/mnt/nemar/openneuro/ds002718/sub-006/eeg/sub-006_task-FaceRecognition_eeg.set', '/mnt/nemar/openneuro/ds002718/sub-007/eeg/sub-007_task-FaceRecognition_eeg.set', '/mnt/nemar/openneuro/ds002718/sub-008/eeg/sub-008_task-FaceRecognition_eeg.set', '/mnt/nemar/openneuro/ds002718/sub-009/eeg/sub-009_task-FaceRecognition_eeg.set', '/mnt/nemar/openneuro/ds002718/sub-010/eeg/sub-010_task-FaceRecognition_eeg.set', '/mnt/nemar/openneuro/ds002718/sub-011/eeg/sub-011_task-FaceRecognition_eeg.set', '/mnt/nemar/openneuro/ds002718/sub-012/eeg/sub-012_task-FaceRecognition_eeg.set', '/mnt/nemar/openneuro/ds002718/sub-013/eeg/sub-013_task-FaceRecognition_eeg.set', '/mnt/nemar/openneuro/ds002718/sub-014/eeg/sub-014_task-FaceRecognition_eeg.set', '/mnt/nemar/openneuro/ds002718/sub-015/eeg/sub-015_task-FaceRecognition_eeg.set', '/mnt/nemar/openneuro/ds002718/sub-016/eeg/sub-016_task-FaceRecognition_eeg.set', '/mnt/nemar/openneuro/ds002718/sub-017/eeg/sub-017_task-FaceRecognition_eeg.set', '/mnt/nemar/openneuro/ds002718/sub-018/eeg/sub-018_task-FaceRecognition_eeg.set', '/mnt/nemar/openneuro/ds002718/sub-019/eeg/sub-019_task-FaceRecognition_eeg.set']
# ['/mnt/nemar/openneuro/ds004770/sub-01/ses-base/ieeg/sub-01_ses-base_task-game_run-01_ieeg.edf', '/mnt/nemar/openneuro/ds004770/sub-01/ses-task/ieeg/sub-01_ses-task_task-game_run-01_ieeg.edf', '/mnt/nemar/openneuro/ds004770/sub-02/ses-base/ieeg/sub-02_ses-base_task-game_run-01_ieeg.edf', '/mnt/nemar/openneuro/ds004770/sub-02/ses-task/ieeg/sub-02_ses-task_task-game_run-01_ieeg.edf', '/mnt/nemar/openneuro/ds004770/sub-02/ses-task/ieeg/sub-02_ses-task_task-game_run-02_ieeg.edf', '/mnt/nemar/openneuro/ds004770/sub-03/ses-base/ieeg/sub-03_ses-base_task-game_run-01_ieeg.edf', '/mnt/nemar/openneuro/ds004770/sub-03/ses-task/ieeg/sub-03_ses-task_task-game_run-01_ieeg.edf', '/mnt/nemar/openneuro/ds004770/sub-04/ses-base/ieeg/sub-04_ses-base_task-game_run-01_ieeg.edf', '/mnt/nemar/openneuro/ds004770/sub-04/ses-task/ieeg/sub-04_ses-task_task-game_run-01_ieeg.edf', '/mnt/nemar/openneuro/ds004770/sub-05/ses-base/ieeg/sub-05_ses-base_task-game_run-01_ieeg.edf', '/mnt/nemar/openneuro/ds004770/sub-05/ses-task/ieeg/sub-05_ses-task_task-game_run-01_ieeg.edf', '/mnt/nemar/openneuro/ds004770/sub-06/ses-base/ieeg/sub-06_ses-base_task-game_run-01_ieeg.edf', '/mnt/nemar/openneuro/ds004770/sub-06/ses-task/ieeg/sub-06_ses-task_task-game_run-01_ieeg.edf', '/mnt/nemar/openneuro/ds004770/sub-06/ses-task/ieeg/sub-06_ses-task_task-game_run-02_ieeg.edf', '/mnt/nemar/openneuro/ds004770/sub-07/ses-base/ieeg/sub-07_ses-base_task-game_run-01_ieeg.edf', '/mnt/nemar/openneuro/ds004770/sub-07/ses-task/ieeg/sub-07_ses-task_task-game_run-01_ieeg.edf', '/mnt/nemar/openneuro/ds004770/sub-08/ses-base/ieeg/sub-08_ses-base_task-game_run-01_ieeg.edf', '/mnt/nemar/openneuro/ds004770/sub-08/ses-task/ieeg/sub-08_ses-task_task-game_run-01_ieeg.edf', '/mnt/nemar/openneuro/ds004770/sub-09/ses-base/ieeg/sub-09_ses-base_task-game_run-01_ieeg.edf', '/mnt/nemar/openneuro/ds004770/sub-09/ses-task/ieeg/sub-09_ses-task_task-game_run-01_ieeg.edf', '/mnt/nemar/openneuro/ds004770/sub-10/ses-base/ieeg/sub-10_ses-base_task-game_run-01_ieeg.edf', '/mnt/nemar/openneuro/ds004770/sub-10/ses-task/ieeg/sub-10_ses-task_task-game_run-01_ieeg.edf']
# ['/mnt/nemar/openneuro/ds004561/sub-01/eeg/sub-01_task-agencyRT_eeg.vhdr', '/mnt/nemar/openneuro/ds004561/sub-02/eeg/sub-02_task-agencyRT_eeg.vhdr', '/mnt/nemar/openneuro/ds004561/sub-03/eeg/sub-03_task-agencyRT_eeg.vhdr', '/mnt/nemar/openneuro/ds004561/sub-04/eeg/sub-04_task-agencyRT_eeg.vhdr', '/mnt/nemar/openneuro/ds004561/sub-05/eeg/sub-05_task-agencyRT_eeg.vhdr', '/mnt/nemar/openneuro/ds004561/sub-07/eeg/sub-07_task-agencyRT_eeg.vhdr', '/mnt/nemar/openneuro/ds004561/sub-08/eeg/sub-08_task-agencyRT_eeg.vhdr', '/mnt/nemar/openneuro/ds004561/sub-09/eeg/sub-09_task-agencyRT_eeg.vhdr', '/mnt/nemar/openneuro/ds004561/sub-10/eeg/sub-10_task-agencyRT_eeg.vhdr', '/mnt/nemar/openneuro/ds004561/sub-11/eeg/sub-11_task-agencyRT_eeg.vhdr', '/mnt/nemar/openneuro/ds004561/sub-12/eeg/sub-12_task-agencyRT_eeg.vhdr', '/mnt/nemar/openneuro/ds004561/sub-13/eeg/sub-13_task-agencyRT_eeg.vhdr', '/mnt/nemar/openneuro/ds004561/sub-14/eeg/sub-14_task-agencyRT_eeg.vhdr', '/mnt/nemar/openneuro/ds004561/sub-15/eeg/sub-15_task-agencyRT_eeg.vhdr', '/mnt/nemar/openneuro/ds004561/sub-16/eeg/sub-16_task-agencyRT_eeg.vhdr', '/mnt/nemar/openneuro/ds004561/sub-17/eeg/sub-17_task-agencyRT_eeg.vhdr', '/mnt/nemar/openneuro/ds004561/sub-18/eeg/sub-18_task-agencyRT_eeg.vhdr', '/mnt/nemar/openneuro/ds004561/sub-19/eeg/sub-19_task-agencyRT_eeg.vhdr', '/mnt/nemar/openneuro/ds004561/sub-20/eeg/sub-20_task-agencyRT_eeg.vhdr', '/mnt/nemar/openneuro/ds004561/sub-21/eeg/sub-21_task-agencyRT_eeg.vhdr', '/mnt/nemar/openneuro/ds004561/sub-22/eeg/sub-22_task-agencyRT_eeg.vhdr', '/mnt/nemar/openneuro/ds004561/sub-23/eeg/sub-23_task-agencyRT_eeg.vhdr', '/mnt/nemar/openneuro/ds004561/sub-25/eeg/sub-25_task-agencyRT_eeg.vhdr']

# %%
layout = BIDSLayout("/mnt/nemar/openneuro/ds002718")
# get file from path
entities = layout.parse_file_entities(
    "/mnt/nemar/openneuro/ds002718/sub-002/eeg/sub-002_task-FaceRecognition_eeg.set"
)
bidsfile = layout.get(**entities)[0]
print(bidsfile)
# Out:
# <BIDSFile filename='/mnt/nemar/openneuro/ds002718/sub-002/eeg/sub-002_task-FaceRecognition_eeg.set'>

# %%
import pprint

# get general info of a recording
pprint.pprint(bidsfile.get_entities(metadata="all"))
# Out:
# {'CapManufacturer': 'Easycap',
#  'ECGChannelCount': 0,
#  'EEGChannelCount': 70,
#  'EEGGround': 'left collar bone',
#  'EEGPlacementScheme': 'extended 10-10% system',
#  'EEGReference': 'nose',
#  'EMGChannelCount': 0,
#  'EOGChannelCount': 2,
#  'InstitutionAddress': '15 Chaucer Road, Cambridge, UK',
#  'InstitutionName': 'MRC Cognition & Brain Sciences Unit',
#  'MiscChannelCount': 4,
#  'PowerLineFrequency': 50,
#  'RecordingDuration': 2991,
#  'RecordingType': 'continuous',
#  'SamplingFrequency': 250,
#  'SoftwareFilters': {'LowPassFilter': {'cutoff': '350 (Hz)'}},
#  'TaskDescription': 'Subjects viewed stimuli on a screen during six, 7.5 '
#                     'minute runs. The stimuli were photographs of either a '
#                     'famous face (known to most of British or a scrambled '
#                     'face, and appeared for a random duration between 800 and '
#                     '1,000 ms. Subjects were instructed to fixate centrally '
#                     'throughout the experiment. To ensure attention to each '
#                     'stimulus, participants were asked to press one of two '
#                     'keys with either their left or right index finger '
#                     '(assignment counter-balanced across participants). Their '
#                     'key-press was based on how symmetric they regarded each '
#                     'image: pressing one or the other key depending whether '
#                     "they thought the image was 'more' or 'less symmetric' "
#                     'than average.',
#  'TaskName': 'FaceRecognition',
#  'datatype': 'eeg',
#  'extension': '.set',
#  'subject': '002',
#  'suffix': 'eeg',
#  'task': 'FaceRecognition'}

# %%
# get associations doesn't give us all desired bids dependencies
bidsfile.get_associations()
# Out:
# [<BIDSJSONFile filename='/mnt/nemar/openneuro/ds002718/sub-002/eeg/sub-002_task-FaceRecognition_eeg.json'>]

# %%
# top level events.json can't be retrieved from a file level
file_entities = bidsfile.get_entities()
# remove 'datatype'
file_entities.pop("datatype")

file_entities["suffix"] = "events"
file_entities["extension"] = ".json"
print(file_entities)
print(layout.get(**file_entities))
print(layout.get(suffix="events", extension=".json"))

# not all file level metadata files can be retrieved even though they exist
file_entities["suffix"] = "events"
file_entities["extension"] = "tsv"
print(file_entities)
print(layout.get(**file_entities))

file_entities["suffix"] = "electrodes"
file_entities["extension"] = "tsv"
print(file_entities)
print(layout.get(**file_entities))

file_entities["suffix"] = "coordsystem"
file_entities["extension"] = "json"
print(file_entities)
print(layout.get(**file_entities))
# Out:
# {'extension': '.json', 'subject': '002', 'suffix': 'events', 'task': 'FaceRecognition'}
# []
# [<BIDSJSONFile filename='/mnt/nemar/openneuro/ds002718/task-FaceRecognition_events.json'>]
# {'extension': 'tsv', 'subject': '002', 'suffix': 'events', 'task': 'FaceRecognition'}
# [<BIDSDataFile filename='/mnt/nemar/openneuro/ds002718/sub-002/eeg/sub-002_task-FaceRecognition_events.tsv'>]
# {'extension': 'tsv', 'subject': '002', 'suffix': 'electrodes', 'task': 'FaceRecognition'}
# []
# {'extension': 'json', 'subject': '002', 'suffix': 'coordsystem', 'task': 'FaceRecognition'}
# []
