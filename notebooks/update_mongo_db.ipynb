# %% [markdown]
# # This code only updates some fields for ds005514

# %%
# %load_ext autoreload
# %autoreload 2
from eegdash import EEGDash
from eegdash.data_utils import BIDSDataset

def get_desired_bids_info(eegdashObj, record, bidsdataset):
    record_bidspath = record['bidspath']
    bids_filepath = [bidsfile for bidsfile in bidsdataset.files if bidsfile.endswith(record_bidspath)]
    if len(bids_filepath) == 0:
        return None
    bids_filepath = bids_filepath[0]
    return eegdashObj.load_eeg_attrs_from_bids_file(bidsdataset, bids_filepath)

eegdashdata = EEGDash(is_public=False)
datasets = ['ds005507','ds005506', 'ds005510', 'ds005512','ds005505','ds005508','ds005509','ds005514','ds005511']
for dataset in datasets:
    print(dataset)
    records = eegdashdata.findrecord({'dataset': dataset}) # current call
    bidsdataset = BIDSDataset(f'/mnt/nemar/openneuro/{dataset}', dataset)
    for record in records:
        eeg_attrs = get_desired_bids_info(eegdashdata, record, bidsdataset)
        if eeg_attrs:
            # eeg_attrs['schema_ref'] = 'eeg_signal'
            print(eeg_attrs['data_name'])
            eegdashdata.update(eeg_attrs)
# Out:
# ds005507_sub-NDARTK691PJJ_task-FunwithFractals_eeg.set
# ds005507_sub-NDARTK691PJJ_task-DiaryOfAWimpyKid_eeg.set
# ds005507_sub-NDARTK691PJJ_task-surroundSupp_run-1_eeg.set

# %%
from eegdash.data_utils import BIDSDataset
bidsdataset = BIDSDataset('/mnt/nemar/openneuro', 'ds002718')
bidsdataset.files
# Out:
# array(['/mnt/nemar/openneuro/ds002718/sub-014/eeg/sub-014_task-FaceRecognition_eeg.set',
#        '/mnt/nemar/openneuro/ds002718/sub-012/eeg/sub-012_task-FaceRecognition_eeg.set',
#        '/mnt/nemar/openneuro/ds002718/sub-015/eeg/sub-015_task-FaceRecognition_eeg.set',
#        '/mnt/nemar/openneuro/ds002718/sub-008/eeg/sub-008_task-FaceRecognition_eeg.set',
#        '/mnt/nemar/openneuro/ds002718/sub-006/eeg/sub-006_task-FaceRecognition_eeg.set',
#        '/mnt/nemar/openneuro/ds002718/sub-013/eeg/sub-013_task-FaceRecognition_eeg.set',
#        '/mnt/nemar/openneuro/ds002718/sub-004/eeg/sub-004_task-FaceRecognition_eeg.set',
#        '/mnt/nemar/openneuro/ds002718/sub-016/eeg/sub-016_task-FaceRecognition_eeg.set',
#        '/mnt/nemar/openneuro/ds002718/sub-002/eeg/sub-002_task-FaceRecognition_eeg.set',
#        '/mnt/nemar/openneuro/ds002718/sub-018/eeg/sub-018_task-FaceRecognition_eeg.set',
#        '/mnt/nemar/openneuro/ds002718/sub-007/eeg/sub-007_task-FaceRecognition_eeg.set',
#        '/mnt/nemar/openneuro/ds002718/sub-010/eeg/sub-010_task-FaceRecognition_eeg.set',
#        '/mnt/nemar/openneuro/ds002718/sub-017/eeg/sub-017_task-FaceRecognition_eeg.set',
#        '/mnt/nemar/openneuro/ds002718/sub-003/eeg/sub-003_task-FaceRecognition_eeg.set',
#        '/mnt/nemar/openneuro/ds002718/sub-011/eeg/sub-011_task-FaceRecognition_eeg.set',
#        '/mnt/nemar/openneuro/ds002718/sub-005/eeg/sub-005_task-FaceRecognition_eeg.set',
#        '/mnt/nemar/openneuro/ds002718/sub-009/eeg/sub-009_task-FaceRecognition_eeg.set',
#        '/mnt/nemar/openneuro/ds002718/sub-019/eeg/sub-019_task-FaceRecognition_eeg.set'],
#       dtype='<U78')

# %%
def get_desired_bids_info(eegdashObj, record, bidsdataset):
    record_bidspath = record['bidspath']
    bids_filepath = [bidsfile for bidsfile in bidsdataset.files if bidsfile.endswith(record_bidspath)]
    if len(bids_filepath) == 0:
        return None
    bids_filepath = bids_filepath[0]
    return eegdashObj.load_eeg_attrs_from_bids_file(bidsdataset, bids_filepath)

# %% [markdown]
# rerun after corrected format

# %%
for record in records:
    eeg_attrs = get_desired_bids_info(eegdashdata, record, bidsdataset)
    # eeg_attrs['schema_ref'] = 'eeg_signal'
    print(eeg_attrs['data_name'])
    eegdashdata.update(eeg_attrs)
# Out:
# ds002718_sub-014_task-FaceRecognition_eeg.set
# ds002718_sub-012_task-FaceRecognition_eeg.set
# ds002718_sub-015_task-FaceRecognition_eeg.set
# ds002718_sub-008_task-FaceRecognition_eeg.set
# ds002718_sub-006_task-FaceRecognition_eeg.set
# ds002718_sub-013_task-FaceRecognition_eeg.set
# ds002718_sub-004_task-FaceRecognition_eeg.set
# ds002718_sub-016_task-FaceRecognition_eeg.set
# ds002718_sub-002_task-FaceRecognition_eeg.set
# ds002718_sub-018_task-FaceRecognition_eeg.set
# ds002718_sub-007_task-FaceRecognition_eeg.set
# ds002718_sub-010_task-FaceRecognition_eeg.set
# ds002718_sub-017_task-FaceRecognition_eeg.set
# ds002718_sub-003_task-FaceRecognition_eeg.set
# ds002718_sub-011_task-FaceRecognition_eeg.set
# ds002718_sub-005_task-FaceRecognition_eeg.set
# ds002718_sub-009_task-FaceRecognition_eeg.set
# ds002718_sub-019_task-FaceRecognition_eeg.set

# %%
record_dict = get_desired_bids_info(eegdashdata, records[0], bidsdataset)
print(record_dict['data_name'])
# print all keys recursively in record_dict
for key, value in record_dict.items():
    print(key, type(key))
    if type(value) is dict:
        for k, v in value.items():
            print(k, type(k))
# Out:
# ds002718_sub-014_task-FaceRecognition_eeg.set
# data_name <class 'str'>
# dataset <class 'str'>
# bidspath <class 'str'>
# subject <class 'str'>
# task <class 'str'>
# session <class 'str'>
# run <class 'str'>
# modality <class 'str'>
# participant_tsv <class 'str'>
# age <class 'str'>
# gender <class 'str'>
# eeg_json <class 'str'>
# TaskName <class 'str'>
# TaskDescription <class 'str'>
# InstitutionAddress <class 'str'>
# InstitutionName <class 'str'>
# EEGReference <class 'str'>
# EEGGround <class 'str'>
# SamplingFrequency <class 'str'>
# PowerLineFrequency <class 'str'>
# SoftwareFilters <class 'str'>
# EEGPlacementScheme <class 'str'>
# CapManufacturer <class 'str'>
# EEGChannelCount <class 'str'>
# EOGChannelCount <class 'str'>
# RecordingType <class 'str'>
# MiscChannelCount <class 'str'>
# RecordingDuration <class 'str'>
# ECGChannelCount <class 'str'>
# EMGChannelCount <class 'str'>
# channel_tsv <class 'str'>
# name <class 'str'>
# type <class 'str'>
# units <class 'str'>
# rawdatainfo <class 'str'>
# sampling_frequency <class 'str'>
# nchans <class 'str'>
# ntimes <class 'str'>
# channel_types <class 'str'>
# channel_names <class 'str'>

# %%
list(record_dict['channel_tsv']['type'].values())
# Out:
# ['EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'HEOG',
#  'VEOG',
#  'ECG',
#  'ECG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG',
#  'EEG']

# %%
record_dict = get_desired_bids_info(eegdashdata, records[0], bidsdataset)
record_dict['channel_tsv']
# Out:
# {'name': ['EEG001',
#   'EEG002',
#   'EEG003',
#   'EEG004',
#   'EEG005',
#   'EEG006',
#   'EEG007',
#   'EEG008',
#   'EEG009',
#   'EEG010',
#   'EEG011',
#   'EEG012',
#   'EEG013',
#   'EEG014',
#   'EEG015',
#   'EEG016',
#   'EEG017',
#   'EEG018',
#   'EEG019',
#   'EEG020',
#   'EEG021',
#   'EEG022',
#   'EEG023',
#   'EEG024',
#   'EEG025',
#   'EEG026',
#   'EEG027',
#   'EEG028',
#   'EEG029',
#   'EEG030',
#   'EEG031',
#   'EEG032',
#   'EEG033',
#   'EEG034',
#   'EEG035',
#   'EEG036',
#   'EEG037',
#   'EEG038',
#   'EEG039',
#   'EEG040',
#   'EEG041',
#   'EEG042',
#   'EEG043',
#   'EEG044',
#   'EEG045',
#   'EEG046',
#   'EEG047',
#   'EEG048',
#   'EEG049',
#   'EEG050',
#   'EEG051',
#   'EEG052',
#   'EEG053',
#   'EEG054',
#   'EEG055',
#   'EEG056',
#   'EEG057',
#   'EEG058',
#   'EEG059',
#   'EEG060',
#   'EEG061',
#   'EEG062',
#   'EEG063',
#   'EEG064',
#   'EEG065',
#   'EEG066',
#   'EEG067',
#   'EEG068',
#   'EEG069',
#   'EEG070',
#   'EEG071',
#   'EEG072',
#   'EEG073',
#   'EEG074'],
#  'type': ['EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'HEOG',
#   'VEOG',
#   'ECG',
#   'ECG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG',
#   'EEG'],
#  'units': ['microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   nan,
#   nan,
#   nan,
#   nan,
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV',
#   'microV']}
