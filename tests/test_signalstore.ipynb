# %%
# To be able to make edits to repo without having to restart notebook
# %load_ext autoreload
# %autoreload 2
import sys 
sys.path.append('..')
import eegdash
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Working datasets
# - ds004580
# - ds004515
# - ds004745
# - ds002718

# %%
EEGDashInstance = EEGDash()
EEGDashInstance.find({'data_name': 'ds002718_sub-014_task-FaceRecognition_eeg.set'})
# Out:
# Pinged your deployment. You successfully connected to MongoDB!
# Found 1 records
# [{'schema_ref': 'eeg_signal',
#   'data_name': 'ds002718_sub-014_task-FaceRecognition_eeg.set',
#   'dataset': 'ds002718',
#   'subject': '014',
#   'task': 'FaceRecognition',
#   'session': '',
#   'run': '',
#   'modality': 'EEG',
#   'sampling_frequency': 250,
#   'version_timestamp': 0,
#   'has_file': True,
#   'time_of_save': datetime.datetime(2024, 10, 25, 14, 20, 23, 990406, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None}]

# %%
EEGDashInstance.get({'data_name': 'ds002718_sub-014_task-FaceRecognition_eeg.set'})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 EEGDashInstance.get({'data_name': 'ds002718_sub-014_task-FaceRecognition_eeg.set'})
#
# File ~/Documents/EEGLAB/EEG-Dash-Data/tests/../src/eegdash/data_utils.py:28, in EEGDash.get(self, *args)
#      27 def get(self, *args):
# ---> 28     return self.sstore.get(*args)
#
# File ~/Documents/EEGLAB/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:258, in get(self, query, validate)
#     255 def get(self, query:dict, validate=False):
#     256     '''
#     257     query: {
# --> 258         'dataset': 'dsxxxx',
#     259
#     260     }'''
#     261     with self.uow as uow:
#     262         sessions = uow.data.find(query, validate=validate, get_data=True)
#
# ...

# %%
signalstore = SignalstoreBIDS(
    # dbconnectionstring='mongodb://127.0.0.1:27017/?directConnection=true&serverSelectionTimeoutMS=2000&appName=mongosh+2.3.1',
    dbconnectionstring='mongodb+srv://eegdash-user:mdzoMjQcHWTVnKDq@cluster0.vz35p.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0',
    is_public=True,
    local_filesystem=False,
    project_name='eegdash'
)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
signalstore.load_domain_models()
# Out:
# property model:  version_timestamp
# property model:  schema_ref
# property model:  schema_type
# property model:  schema_name
# property model:  schema_title
# property model:  schema_description
# property model:  data_name
# property model:  time_of_save
# property model:  time_of_removal
# property model:  record_type
# property model:  modality
# property model:  json_schema
# property model:  has_file
# property model:  unit_of_measure
# property model:  dimension_of_measure
# property model:  acquisition
# property model:  acquisition_date
# property model:  import_date
# property model:  acquisition_notes
# property model:  data_dimensions
# property model:  shape
# property model:  dtype
# property model:  session_description
# property model:  session_date
# property model:  session_time
# property model:  session_duration
# property model:  session_notes
# property model:  session_run
# property model:  data_ref
# property model:  start_time
# property model:  duration
# ...

# %%
signalstore.add_bids_dataset(dataset='ds002718', data_dir='/mnt/nemar/openneuro/ds002718', raw_format='eeglab', record_only=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 signalstore.add_bids_dataset(dataset='ds002718', data_dir='/mnt/nemar/openneuro/ds002718', raw_format='eeglab', record_only=True)
#
# File ~/Documents/EEGLAB/EEG-Dash-Data/code/signalstore_data_utils.py:179, in SignalstoreBIDS.add_bids_dataset(self, dataset, data_dir, raw_format, overwrite, record_only)
#     177 def add_bids_dataset(self, dataset, data_dir, raw_format='eeglab', overwrite=False, record_only=False):
#     178     if self.is_public:
# --> 179         raise ValueError('This operation is not allowed for public users')
#     181     bids_dataset = BIDSDataset(
#     182         data_dir=data_dir,
#     183         dataset=dataset,
#     184         raw_format=raw_format,
#     185     )
#     186     for bids_file in bids_dataset.get_files():
#
# ...

# %%
signalstore.find({'dataset': 'ds002718'})
# Out:
# Found 18 records
# [{'schema_ref': 'eeg_signal',
#   'data_name': 'ds002718_sub-014_task-FaceRecognition_eeg.set',
#   'dataset': 'ds002718',
#   'subject': '014',
#   'task': 'FaceRecognition',
#   'session': '',
#   'run': '',
#   'modality': 'EEG',
#   'sampling_frequency': 250,
#   'version_timestamp': 0,
#   'has_file': True,
#   'time_of_save': datetime.datetime(2024, 10, 25, 14, 20, 23, 990406, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds002718_sub-012_task-FaceRecognition_eeg.set',
#   'dataset': 'ds002718',
#   'subject': '012',
#   'task': 'FaceRecognition',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 250,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2024, 10, 25, 14, 38, 37, 582636, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
# ...

# %%
signalstore.find({'data_name': 'ds002718_sub-014_task-FaceRecognition_eeg.set'})
# Out:
# Found 1 records
# [{'schema_ref': 'eeg_signal',
#   'data_name': 'ds002718_sub-014_task-FaceRecognition_eeg.set',
#   'dataset': 'ds002718',
#   'subject': '014',
#   'task': 'FaceRecognition',
#   'session': '',
#   'run': '',
#   'modality': 'EEG',
#   'sampling_frequency': 250,
#   'version_timestamp': 0,
#   'has_file': True,
#   'time_of_save': datetime.datetime(2024, 10, 25, 14, 20, 23, 990406, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None}]

# %%
data = signalstore.get({'data_name': 'ds002718_sub-014_task-FaceRecognition_eeg.set'})
print(data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 data = signalstore.get({'data_name': 'ds002718_sub-014_task-FaceRecognition_eeg.set'})
#       2 print(data)
#
# File ~/Documents/EEGLAB/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:258, in get(self, query, validate)
#     255 def get(self, query:dict, validate=False):
#     256     '''
#     257     query: {
# --> 258         'dataset': 'dsxxxx',
#     259
#     260     }'''
#     261     with self.uow as uow:
#     262         sessions = uow.data.find(query, validate=validate, get_data=True)
#
# File ~/Documents/EEGLAB/EEG-Dash-Data/eegdash/signalstore/store/repositories.py:543, in find(self, filter, projection, sort, limit, get_data, validate)
#
# ...

# %%
raw_data = data[0].values
raw_data.shape
# Out:
# (74, 742500)

# %%
data = signalstore.get({'dataset': 'ds002718'})
# Out:
# Found 18 records

# %%
data[3]
# Out:
# <xarray.DataArray 'eeg_signal__ds002718_sub-008_task-FaceRecognition_eeg.set' (
#                                                                                channel: 74,
#                                                                                time: 738750)> Size: 437MB
# [54667500 values with dtype=float64]
# Coordinates:
#   * channel  (channel) object 592B 'EEG001' 'EEG002' ... 'EEG073' 'EEG074'
#   * time     (time) float64 6MB 0.0 0.004 0.008 ... 2.955e+03 2.955e+03
# Attributes:
#     data_name:           ds002718_sub-008_task-FaceRecognition_eeg.set
#     has_file:            True
#     modality:            EEG
#     run:
#     sampling_frequency:  250
#     schema_ref:          eeg_signal
#     session:
#     subject:             8
#     task:                FaceRecognition
#     version_timestamp:   0

# %%
signalstore_aws = SignalstoreBIDS(
    dbconnectionstring='mongodb://23.21.113.214:27017/?directConnection=true&serverSelectionTimeoutMS=2000&appName=mongosh+2.2.1',
    local_filesystem=False,
    project_name='eegdash',
)

# %%
signalstore_aws.find({'task': 'FaceRecognition'})
# Out:
# []

# %%
signalstore_local = SignalstoreBIDS(
    dbconnectionstring='mongodb://127.0.0.1:27017/?directConnection=true&serverSelectionTimeoutMS=2000&appName=mongosh+2.3.1',
    local_filesystem=True,
    project_name='eegdash'
)

# %%
signalstore_local.add_bids_dataset(dataset='ds004745', data_dir='/mnt/nemar/openneuro/ds004745', raw_format='eeglab')
# Out:
# Scanning 1 directories... [PosixPath('/mnt/nemar/openneuro/ds004745')]
# Current number of files: 0
# Scanning 7 directories... ['/mnt/nemar/openneuro/ds004745/sub-001', '/mnt/nemar/openneuro/ds004745/sub-006', '/mnt/nemar/openneuro/ds004745/.datalad', '/mnt/nemar/openneuro/ds004745/sub-004', '/mnt/nemar/openneuro/ds004745/sub-002', '/mnt/nemar/openneuro/ds004745/sub-003', '/mnt/nemar/openneuro/ds004745/sub-005']
# Current number of files: 0
# Scanning 6 directories... ['/mnt/nemar/openneuro/ds004745/sub-001/eeg', '/mnt/nemar/openneuro/ds004745/sub-006/eeg', '/mnt/nemar/openneuro/ds004745/sub-004/eeg', '/mnt/nemar/openneuro/ds004745/sub-002/eeg', '/mnt/nemar/openneuro/ds004745/sub-003/eeg', '/mnt/nemar/openneuro/ds004745/sub-005/eeg']
# Adding  /mnt/nemar/openneuro/ds004745/sub-006/eeg/sub-006_task-unnamed_eeg.set
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 32 concurrent workers.
# ...

# %%
signalstore_local.find({})
# Out:
# []
