# %%
# To be able to make edits to repo without having to restart notebook
# %load_ext autoreload
# %autoreload 2
# import sys 
# sys.path.append('..')
from eegdash.signalstore_data_utils import SignalstoreBIDS
from eegdash.signalstore_data_utils import SignalstoreOpenneuro

# %% [markdown]
# ## Working datasets
# - ds002718
# - ds005505

# %%
signalstore = SignalstoreOpenneuro(
    is_public=False,
    local_filesystem=False,
)
# signalstore = SignalstoreBIDS(
#     is_public=False,
#     local_filesystem=False,
# )
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
# Ingesting to MongoDB
# signalstore.add_bids_dataset(dataset='ds002718', data_dir='/mnt/nemar/openneuro/ds002718', raw_format='eeglab')

# %%
signalstore.find({'task': 'RestingState'})
# Out:
# Found 752 records
# [{'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARRD326KB9_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARRD326KB9/eeg/sub-NDARRD326KB9_task-RestingState_eeg.set',
#   'subject': 'NDARRD326KB9',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 16, 23, 55, 3, 296858, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARZD415ZZ1_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARZD415ZZ1/eeg/sub-NDARZD415ZZ1_task-RestingState_eeg.set',
#   'subject': 'NDARZD415ZZ1',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 16, 23, 55, 27, 995722, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARXH597ML1_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARXH597ML1/eeg/sub-NDARXH597ML1_task-RestingState_eeg.set',
#   'subject': 'NDARXH597ML1',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 16, 23, 55, 29, 385034, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARBX400RTC_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARBX400RTC/eeg/sub-NDARBX400RTC_task-RestingState_eeg.set',
#   'subject': 'NDARBX400RTC',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 16, 23, 55, 38, 931722, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARVD685RRJ_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARVD685RRJ/eeg/sub-NDARVD685RRJ_task-RestingState_eeg.set',
#   'subject': 'NDARVD685RRJ',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 16, 23, 55, 48, 579916, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARPC817XZ5_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARPC817XZ5/eeg/sub-NDARPC817XZ5_task-RestingState_eeg.set',
#   'subject': 'NDARPC817XZ5',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 16, 23, 56, 5, 310650, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARBK082PDD_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARBK082PDD/eeg/sub-NDARBK082PDD_task-RestingState_eeg.set',
#   'subject': 'NDARBK082PDD',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 16, 23, 56, 16, 327738, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARPL306LC6_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARPL306LC6/eeg/sub-NDARPL306LC6_task-RestingState_eeg.set',
#   'subject': 'NDARPL306LC6',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 16, 23, 56, 46, 450929, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARUW904FMQ_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARUW904FMQ/eeg/sub-NDARUW904FMQ_task-RestingState_eeg.set',
#   'subject': 'NDARUW904FMQ',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 16, 23, 56, 53, 427189, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARCJ594BWQ_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARCJ594BWQ/eeg/sub-NDARCJ594BWQ_task-RestingState_eeg.set',
#   'subject': 'NDARCJ594BWQ',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 16, 23, 57, 16, 660533, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARCZ947WU5_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARCZ947WU5/eeg/sub-NDARCZ947WU5_task-RestingState_eeg.set',
#   'subject': 'NDARCZ947WU5',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 16, 23, 57, 20, 865272, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARYZ770NA1_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARYZ770NA1/eeg/sub-NDARYZ770NA1_task-RestingState_eeg.set',
#   'subject': 'NDARYZ770NA1',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 16, 23, 57, 45, 759978, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARET632ELD_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARET632ELD/eeg/sub-NDARET632ELD_task-RestingState_eeg.set',
#   'subject': 'NDARET632ELD',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 16, 23, 57, 59, 577992, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARXZ685TU4_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARXZ685TU4/eeg/sub-NDARXZ685TU4_task-RestingState_eeg.set',
#   'subject': 'NDARXZ685TU4',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 16, 23, 58, 20, 183391, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARCE721YB5_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARCE721YB5/eeg/sub-NDARCE721YB5_task-RestingState_eeg.set',
#   'subject': 'NDARCE721YB5',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 16, 23, 58, 35, 542903, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARAW320CGR_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARAW320CGR/eeg/sub-NDARAW320CGR_task-RestingState_eeg.set',
#   'subject': 'NDARAW320CGR',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 16, 23, 58, 41, 98760, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARBM173BJG_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARBM173BJG/eeg/sub-NDARBM173BJG_task-RestingState_eeg.set',
#   'subject': 'NDARBM173BJG',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 16, 23, 59, 4, 505462, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARLV387GP4_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARLV387GP4/eeg/sub-NDARLV387GP4_task-RestingState_eeg.set',
#   'subject': 'NDARLV387GP4',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 16, 23, 59, 8, 679221, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARUR987CDM_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARUR987CDM/eeg/sub-NDARUR987CDM_task-RestingState_eeg.set',
#   'subject': 'NDARUR987CDM',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 16, 23, 59, 25, 88309, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARYD546HCB_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARYD546HCB/eeg/sub-NDARYD546HCB_task-RestingState_eeg.set',
#   'subject': 'NDARYD546HCB',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 16, 23, 59, 29, 208097, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARJK910PDK_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARJK910PDK/eeg/sub-NDARJK910PDK_task-RestingState_eeg.set',
#   'subject': 'NDARJK910PDK',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 16, 23, 59, 45, 609607, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARGJ627BL2_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARGJ627BL2/eeg/sub-NDARGJ627BL2_task-RestingState_eeg.set',
#   'subject': 'NDARGJ627BL2',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 16, 23, 59, 57, 8133, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARCA153NKE_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARCA153NKE/eeg/sub-NDARCA153NKE_task-RestingState_eeg.set',
#   'subject': 'NDARCA153NKE',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 0, 6, 640578, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARMD575AXD_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARMD575AXD/eeg/sub-NDARMD575AXD_task-RestingState_eeg.set',
#   'subject': 'NDARMD575AXD',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 0, 22, 985986, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARHR753ZKU_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARHR753ZKU/eeg/sub-NDARHR753ZKU_task-RestingState_eeg.set',
#   'subject': 'NDARHR753ZKU',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 0, 28, 745487, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARDL511UND_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARDL511UND/eeg/sub-NDARDL511UND_task-RestingState_eeg.set',
#   'subject': 'NDARDL511UND',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 0, 47, 817313, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARFK610GY5_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARFK610GY5/eeg/sub-NDARFK610GY5_task-RestingState_eeg.set',
#   'subject': 'NDARFK610GY5',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 1, 2, 865058, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARFT581ZW5_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARFT581ZW5/eeg/sub-NDARFT581ZW5_task-RestingState_eeg.set',
#   'subject': 'NDARFT581ZW5',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 1, 27, 505966, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARXY938XY7_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARXY938XY7/eeg/sub-NDARXY938XY7_task-RestingState_eeg.set',
#   'subject': 'NDARXY938XY7',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 1, 35, 708981, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARYF135ZHU_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARYF135ZHU/eeg/sub-NDARYF135ZHU_task-RestingState_eeg.set',
#   'subject': 'NDARYF135ZHU',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 1, 57, 516703, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARZC499NVX_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARZC499NVX/eeg/sub-NDARZC499NVX_task-RestingState_eeg.set',
#   'subject': 'NDARZC499NVX',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 2, 9, 839452, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARWP954GPJ_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARWP954GPJ/eeg/sub-NDARWP954GPJ_task-RestingState_eeg.set',
#   'subject': 'NDARWP954GPJ',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 2, 18, 126475, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARZH761YA7_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARZH761YA7/eeg/sub-NDARZH761YA7_task-RestingState_eeg.set',
#   'subject': 'NDARZH761YA7',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 2, 30, 661294, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARCJ475WJP_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARCJ475WJP/eeg/sub-NDARCJ475WJP_task-RestingState_eeg.set',
#   'subject': 'NDARCJ475WJP',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 2, 41, 603278, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARUT607MWK_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARUT607MWK/eeg/sub-NDARUT607MWK_task-RestingState_eeg.set',
#   'subject': 'NDARUT607MWK',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 2, 55, 473490, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARXR965TFK_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARXR965TFK/eeg/sub-NDARXR965TFK_task-RestingState_eeg.set',
#   'subject': 'NDARXR965TFK',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 3, 6, 492699, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARZV608BL8_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARZV608BL8/eeg/sub-NDARZV608BL8_task-RestingState_eeg.set',
#   'subject': 'NDARZV608BL8',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 3, 28, 350543, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARUN300FG1_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARUN300FG1/eeg/sub-NDARUN300FG1_task-RestingState_eeg.set',
#   'subject': 'NDARUN300FG1',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 3, 31, 187968, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARRL660CME_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARRL660CME/eeg/sub-NDARRL660CME_task-RestingState_eeg.set',
#   'subject': 'NDARRL660CME',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 3, 47, 569861, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARDV088AA3_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARDV088AA3/eeg/sub-NDARDV088AA3_task-RestingState_eeg.set',
#   'subject': 'NDARDV088AA3',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 4, 0, 134357, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARJU805JG5_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARJU805JG5/eeg/sub-NDARJU805JG5_task-RestingState_eeg.set',
#   'subject': 'NDARJU805JG5',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 4, 9, 727832, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARUN221VCJ_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARUN221VCJ/eeg/sub-NDARUN221VCJ_task-RestingState_eeg.set',
#   'subject': 'NDARUN221VCJ',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 4, 17, 931504, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARVB297WUM_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARVB297WUM/eeg/sub-NDARVB297WUM_task-RestingState_eeg.set',
#   'subject': 'NDARVB297WUM',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 4, 27, 647612, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARCJ170CT9_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARCJ170CT9/eeg/sub-NDARCJ170CT9_task-RestingState_eeg.set',
#   'subject': 'NDARCJ170CT9',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 4, 39, 994272, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARGB441VVD_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARGB441VVD/eeg/sub-NDARGB441VVD_task-RestingState_eeg.set',
#   'subject': 'NDARGB441VVD',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 4, 57, 815575, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARCR499NE4_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARCR499NE4/eeg/sub-NDARCR499NE4_task-RestingState_eeg.set',
#   'subject': 'NDARCR499NE4',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 5, 11, 532410, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARUX216VHK_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARUX216VHK/eeg/sub-NDARUX216VHK_task-RestingState_eeg.set',
#   'subject': 'NDARUX216VHK',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 5, 26, 600901, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARVX337AC0_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARVX337AC0/eeg/sub-NDARVX337AC0_task-RestingState_eeg.set',
#   'subject': 'NDARVX337AC0',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 5, 40, 361911, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARYT885XH3_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARYT885XH3/eeg/sub-NDARYT885XH3_task-RestingState_eeg.set',
#   'subject': 'NDARYT885XH3',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 5, 52, 668986, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARTF133LLM_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARTF133LLM/eeg/sub-NDARTF133LLM_task-RestingState_eeg.set',
#   'subject': 'NDARTF133LLM',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 6, 14, 574634, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARWX338NDL_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARWX338NDL/eeg/sub-NDARWX338NDL_task-RestingState_eeg.set',
#   'subject': 'NDARWX338NDL',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 6, 26, 963028, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARAC904DMU_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARAC904DMU/eeg/sub-NDARAC904DMU_task-RestingState_eeg.set',
#   'subject': 'NDARAC904DMU',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 6, 51, 685340, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARAP359UM6_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARAP359UM6/eeg/sub-NDARAP359UM6_task-RestingState_eeg.set',
#   'subject': 'NDARAP359UM6',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 7, 2, 719560, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARRM467NP2_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARRM467NP2/eeg/sub-NDARRM467NP2_task-RestingState_eeg.set',
#   'subject': 'NDARRM467NP2',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 7, 13, 664952, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARNR773DL4_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARNR773DL4/eeg/sub-NDARNR773DL4_task-RestingState_eeg.set',
#   'subject': 'NDARNR773DL4',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 7, 20, 555852, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARWW003WWW_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARWW003WWW/eeg/sub-NDARWW003WWW_task-RestingState_eeg.set',
#   'subject': 'NDARWW003WWW',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 7, 31, 494614, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARBD879MBX_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARBD879MBX/eeg/sub-NDARBD879MBX_task-RestingState_eeg.set',
#   'subject': 'NDARBD879MBX',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 7, 45, 269457, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARMR491LM5_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARMR491LM5/eeg/sub-NDARMR491LM5_task-RestingState_eeg.set',
#   'subject': 'NDARMR491LM5',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 7, 58, 995256, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARGR106TJB_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARGR106TJB/eeg/sub-NDARGR106TJB_task-RestingState_eeg.set',
#   'subject': 'NDARGR106TJB',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 8, 8, 681933, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDAREG561ML5_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDAREG561ML5/eeg/sub-NDAREG561ML5_task-RestingState_eeg.set',
#   'subject': 'NDAREG561ML5',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 8, 19, 701770, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARAM704GKZ_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARAM704GKZ/eeg/sub-NDARAM704GKZ_task-RestingState_eeg.set',
#   'subject': 'NDARAM704GKZ',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 8, 41, 571079, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARLH979WFX_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARLH979WFX/eeg/sub-NDARLH979WFX_task-RestingState_eeg.set',
#   'subject': 'NDARLH979WFX',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 8, 52, 600525, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARTP313AGH_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARTP313AGH/eeg/sub-NDARTP313AGH_task-RestingState_eeg.set',
#   'subject': 'NDARTP313AGH',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 9, 9, 38014, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARKA627LF8_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARKA627LF8/eeg/sub-NDARKA627LF8_task-RestingState_eeg.set',
#   'subject': 'NDARKA627LF8',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 9, 28, 162507, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARFW972KFQ_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARFW972KFQ/eeg/sub-NDARFW972KFQ_task-RestingState_eeg.set',
#   'subject': 'NDARFW972KFQ',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 9, 44, 571943, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDAREN519BLJ_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDAREN519BLJ/eeg/sub-NDAREN519BLJ_task-RestingState_eeg.set',
#   'subject': 'NDAREN519BLJ',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 9, 51, 721876, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARLL720BGU_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARLL720BGU/eeg/sub-NDARLL720BGU_task-RestingState_eeg.set',
#   'subject': 'NDARLL720BGU',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 10, 16, 393505, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARWA622HHZ_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARWA622HHZ/eeg/sub-NDARWA622HHZ_task-RestingState_eeg.set',
#   'subject': 'NDARWA622HHZ',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 10, 27, 395540, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARGD507TDZ_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARGD507TDZ/eeg/sub-NDARGD507TDZ_task-RestingState_eeg.set',
#   'subject': 'NDARGD507TDZ',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 10, 35, 629063, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARFD316UD2_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARFD316UD2/eeg/sub-NDARFD316UD2_task-RestingState_eeg.set',
#   'subject': 'NDARFD316UD2',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 10, 50, 735241, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARTX934NH6_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARTX934NH6/eeg/sub-NDARTX934NH6_task-RestingState_eeg.set',
#   'subject': 'NDARTX934NH6',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 10, 59, 46940, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARNW687HMZ_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARNW687HMZ/eeg/sub-NDARNW687HMZ_task-RestingState_eeg.set',
#   'subject': 'NDARNW687HMZ',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 11, 4, 736865, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARZX561DR9_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARZX561DR9/eeg/sub-NDARZX561DR9_task-RestingState_eeg.set',
#   'subject': 'NDARZX561DR9',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 11, 15, 742148, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARXY162ERA_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARXY162ERA/eeg/sub-NDARXY162ERA_task-RestingState_eeg.set',
#   'subject': 'NDARXY162ERA',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 11, 25, 413076, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARGB040MGR_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARGB040MGR/eeg/sub-NDARGB040MGR_task-RestingState_eeg.set',
#   'subject': 'NDARGB040MGR',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 11, 54, 93964, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARJM828PAL_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARJM828PAL/eeg/sub-NDARJM828PAL_task-RestingState_eeg.set',
#   'subject': 'NDARJM828PAL',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 11, 55, 531061, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARTD468TUH_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARTD468TUH/eeg/sub-NDARTD468TUH_task-RestingState_eeg.set',
#   'subject': 'NDARTD468TUH',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 12, 2, 439689, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARZJ016GL0_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARZJ016GL0/eeg/sub-NDARZJ016GL0_task-RestingState_eeg.set',
#   'subject': 'NDARZJ016GL0',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 12, 18, 876235, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARBX121UM9_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARBX121UM9/eeg/sub-NDARBX121UM9_task-RestingState_eeg.set',
#   'subject': 'NDARBX121UM9',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 12, 33, 914249, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARTX659HAF_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARTX659HAF/eeg/sub-NDARTX659HAF_task-RestingState_eeg.set',
#   'subject': 'NDARTX659HAF',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 12, 46, 351750, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARKM635UY0_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARKM635UY0/eeg/sub-NDARKM635UY0_task-RestingState_eeg.set',
#   'subject': 'NDARKM635UY0',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 13, 5, 441828, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARWV405ZW0_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARWV405ZW0/eeg/sub-NDARWV405ZW0_task-RestingState_eeg.set',
#   'subject': 'NDARWV405ZW0',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 13, 23, 248508, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARPN418ZKT_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARPN418ZKT/eeg/sub-NDARPN418ZKT_task-RestingState_eeg.set',
#   'subject': 'NDARPN418ZKT',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 13, 24, 677605, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARKD134TCX_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARKD134TCX/eeg/sub-NDARKD134TCX_task-RestingState_eeg.set',
#   'subject': 'NDARKD134TCX',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 13, 39, 709321, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARAG143ARJ_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARAG143ARJ/eeg/sub-NDARAG143ARJ_task-RestingState_eeg.set',
#   'subject': 'NDARAG143ARJ',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 13, 53, 405317, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARYL758JGG_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARYL758JGG/eeg/sub-NDARYL758JGG_task-RestingState_eeg.set',
#   'subject': 'NDARYL758JGG',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 14, 7, 54993, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARCN669XPR_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARCN669XPR/eeg/sub-NDARCN669XPR_task-RestingState_eeg.set',
#   'subject': 'NDARCN669XPR',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 14, 35, 720460, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARCW071AU5_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARCW071AU5/eeg/sub-NDARCW071AU5_task-RestingState_eeg.set',
#   'subject': 'NDARCW071AU5',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 14, 37, 178095, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARRP818DWL_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARRP818DWL/eeg/sub-NDARRP818DWL_task-RestingState_eeg.set',
#   'subject': 'NDARRP818DWL',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 14, 57, 675175, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARGL800LDW_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARGL800LDW/eeg/sub-NDARGL800LDW_task-RestingState_eeg.set',
#   'subject': 'NDARGL800LDW',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 15, 7, 241855, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARWW005GCU_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARWW005GCU/eeg/sub-NDARWW005GCU_task-RestingState_eeg.set',
#   'subject': 'NDARWW005GCU',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 0, 15, 30, 365365, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005505_sub-NDARXG469XGP_task-RestingState_eeg.set',
#   'dataset': 'ds005505',
#   'bidspath': 'ds005505/sub-NDARXG469XGP/eeg/sub-NDARXG469XGP_task-RestingState_eeg.set',
#   'subject': 'NDARXG469XGP',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
# ...
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 13, 27, 27, 281768, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005510_sub-NDARAY283AU1_task-RestingState_eeg.set',
#   'dataset': 'ds005510',
#   'bidspath': 'ds005510/sub-NDARAY283AU1/eeg/sub-NDARAY283AU1_task-RestingState_eeg.set',
#   'subject': 'NDARAY283AU1',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 13, 27, 34, 128889, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005510_sub-NDARKM250ET5_task-RestingState_eeg.set',
#   'dataset': 'ds005510',
#   'bidspath': 'ds005510/sub-NDARKM250ET5/eeg/sub-NDARKM250ET5_task-RestingState_eeg.set',
#   'subject': 'NDARKM250ET5',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 13, 27, 53, 115117, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005510_sub-NDARLY947EXR_task-RestingState_eeg.set',
#   'dataset': 'ds005510',
#   'bidspath': 'ds005510/sub-NDARLY947EXR/eeg/sub-NDARLY947EXR_task-RestingState_eeg.set',
#   'subject': 'NDARLY947EXR',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 13, 28, 7, 952717, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005510_sub-NDAREW661NZJ_task-RestingState_eeg.set',
#   'dataset': 'ds005510',
#   'bidspath': 'ds005510/sub-NDAREW661NZJ/eeg/sub-NDAREW661NZJ_task-RestingState_eeg.set',
#   'subject': 'NDAREW661NZJ',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 13, 28, 10, 672056, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005510_sub-NDARFL793LDE_task-RestingState_eeg.set',
#   'dataset': 'ds005510',
#   'bidspath': 'ds005510/sub-NDARFL793LDE/eeg/sub-NDARFL793LDE_task-RestingState_eeg.set',
#   'subject': 'NDARFL793LDE',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 13, 28, 18, 852972, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005510_sub-NDARTV776ZJ8_task-RestingState_eeg.set',
#   'dataset': 'ds005510',
#   'bidspath': 'ds005510/sub-NDARTV776ZJ8/eeg/sub-NDARTV776ZJ8_task-RestingState_eeg.set',
#   'subject': 'NDARTV776ZJ8',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 13, 28, 31, 34119, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005510_sub-NDARVP109DF0_task-RestingState_eeg.set',
#   'dataset': 'ds005510',
#   'bidspath': 'ds005510/sub-NDARVP109DF0/eeg/sub-NDARVP109DF0_task-RestingState_eeg.set',
#   'subject': 'NDARVP109DF0',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 13, 28, 37, 866288, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005510_sub-NDARYN152YMW_task-RestingState_eeg.set',
#   'dataset': 'ds005510',
#   'bidspath': 'ds005510/sub-NDARYN152YMW/eeg/sub-NDARYN152YMW_task-RestingState_eeg.set',
#   'subject': 'NDARYN152YMW',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 13, 28, 59, 531422, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005510_sub-NDARCL008HLA_task-RestingState_eeg.set',
#   'dataset': 'ds005510',
#   'bidspath': 'ds005510/sub-NDARCL008HLA/eeg/sub-NDARCL008HLA_task-RestingState_eeg.set',
#   'subject': 'NDARCL008HLA',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 13, 29, 9, 41244, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005510_sub-NDARMH364EMW_task-RestingState_eeg.set',
#   'dataset': 'ds005510',
#   'bidspath': 'ds005510/sub-NDARMH364EMW/eeg/sub-NDARMH364EMW_task-RestingState_eeg.set',
#   'subject': 'NDARMH364EMW',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 13, 29, 24, 242799, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005510_sub-NDARDZ147ETZ_task-RestingState_eeg.set',
#   'dataset': 'ds005510',
#   'bidspath': 'ds005510/sub-NDARDZ147ETZ/eeg/sub-NDARDZ147ETZ_task-RestingState_eeg.set',
#   'subject': 'NDARDZ147ETZ',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 13, 29, 36, 438730, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005510_sub-NDARWX173EFW_task-RestingState_eeg.set',
#   'dataset': 'ds005510',
#   'bidspath': 'ds005510/sub-NDARWX173EFW/eeg/sub-NDARWX173EFW_task-RestingState_eeg.set',
#   'subject': 'NDARWX173EFW',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 13, 29, 58, 118644, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005510_sub-NDARUT651WFC_task-RestingState_eeg.set',
#   'dataset': 'ds005510',
#   'bidspath': 'ds005510/sub-NDARUT651WFC/eeg/sub-NDARUT651WFC_task-RestingState_eeg.set',
#   'subject': 'NDARUT651WFC',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 13, 30, 3, 589936, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005510_sub-NDARFU786BN4_task-RestingState_eeg.set',
#   'dataset': 'ds005510',
#   'bidspath': 'ds005510/sub-NDARFU786BN4/eeg/sub-NDARFU786BN4_task-RestingState_eeg.set',
#   'subject': 'NDARFU786BN4',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 13, 30, 11, 722963, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005510_sub-NDARKB614KGY_task-RestingState_eeg.set',
#   'dataset': 'ds005510',
#   'bidspath': 'ds005510/sub-NDARKB614KGY/eeg/sub-NDARKB614KGY_task-RestingState_eeg.set',
#   'subject': 'NDARKB614KGY',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 13, 30, 19, 900677, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005510_sub-NDARWV938NKD_task-RestingState_eeg.set',
#   'dataset': 'ds005510',
#   'bidspath': 'ds005510/sub-NDARWV938NKD/eeg/sub-NDARWV938NKD_task-RestingState_eeg.set',
#   'subject': 'NDARWV938NKD',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 13, 30, 46, 938844, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005510_sub-NDARHF545HFW_task-RestingState_eeg.set',
#   'dataset': 'ds005510',
#   'bidspath': 'ds005510/sub-NDARHF545HFW/eeg/sub-NDARHF545HFW_task-RestingState_eeg.set',
#   'subject': 'NDARHF545HFW',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 13, 30, 52, 422031, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005510_sub-NDARGV436PFT_task-RestingState_eeg.set',
#   'dataset': 'ds005510',
#   'bidspath': 'ds005510/sub-NDARGV436PFT/eeg/sub-NDARGV436PFT_task-RestingState_eeg.set',
#   'subject': 'NDARGV436PFT',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 13, 31, 18, 737470, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005510_sub-NDARUC022JWT_task-RestingState_eeg.set',
#   'dataset': 'ds005510',
#   'bidspath': 'ds005510/sub-NDARUC022JWT/eeg/sub-NDARUC022JWT_task-RestingState_eeg.set',
#   'subject': 'NDARUC022JWT',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 13, 31, 26, 924923, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005510_sub-NDARPH474YF3_task-RestingState_eeg.set',
#   'dataset': 'ds005510',
#   'bidspath': 'ds005510/sub-NDARPH474YF3/eeg/sub-NDARPH474YF3_task-RestingState_eeg.set',
#   'subject': 'NDARPH474YF3',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 13, 31, 37, 770044, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005510_sub-NDARJJ817UP1_task-RestingState_eeg.set',
#   'dataset': 'ds005510',
#   'bidspath': 'ds005510/sub-NDARJJ817UP1/eeg/sub-NDARJJ817UP1_task-RestingState_eeg.set',
#   'subject': 'NDARJJ817UP1',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 13, 31, 56, 734414, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005510_sub-NDARFD453NPR_task-RestingState_eeg.set',
#   'dataset': 'ds005510',
#   'bidspath': 'ds005510/sub-NDARFD453NPR/eeg/sub-NDARFD453NPR_task-RestingState_eeg.set',
#   'subject': 'NDARFD453NPR',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 13, 32, 4, 906624, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005510_sub-NDARNB674VMY_task-RestingState_eeg.set',
#   'dataset': 'ds005510',
#   'bidspath': 'ds005510/sub-NDARNB674VMY/eeg/sub-NDARNB674VMY_task-RestingState_eeg.set',
#   'subject': 'NDARNB674VMY',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 13, 32, 14, 370513, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005510_sub-NDARJA737FAJ_task-RestingState_eeg.set',
#   'dataset': 'ds005510',
#   'bidspath': 'ds005510/sub-NDARJA737FAJ/eeg/sub-NDARJA737FAJ_task-RestingState_eeg.set',
#   'subject': 'NDARJA737FAJ',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 13, 32, 17, 131216, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005510_sub-NDARFR301KKP_task-RestingState_eeg.set',
#   'dataset': 'ds005510',
#   'bidspath': 'ds005510/sub-NDARFR301KKP/eeg/sub-NDARFR301KKP_task-RestingState_eeg.set',
#   'subject': 'NDARFR301KKP',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 13, 32, 36, 124253, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005510_sub-NDARVD194JX2_task-RestingState_eeg.set',
#   'dataset': 'ds005510',
#   'bidspath': 'ds005510/sub-NDARVD194JX2/eeg/sub-NDARVD194JX2_task-RestingState_eeg.set',
#   'subject': 'NDARVD194JX2',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 13, 32, 57, 775304, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005510_sub-NDARHW575ZJ5_task-RestingState_eeg.set',
#   'dataset': 'ds005510',
#   'bidspath': 'ds005510/sub-NDARHW575ZJ5/eeg/sub-NDARHW575ZJ5_task-RestingState_eeg.set',
#   'subject': 'NDARHW575ZJ5',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 13, 33, 3, 175824, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005510_sub-NDARKC978MR4_task-RestingState_eeg.set',
#   'dataset': 'ds005510',
#   'bidspath': 'ds005510/sub-NDARKC978MR4/eeg/sub-NDARKC978MR4_task-RestingState_eeg.set',
#   'subject': 'NDARKC978MR4',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 13, 33, 8, 583211, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005510_sub-NDARTH433TE0_task-RestingState_eeg.set',
#   'dataset': 'ds005510',
#   'bidspath': 'ds005510/sub-NDARTH433TE0/eeg/sub-NDARTH433TE0_task-RestingState_eeg.set',
#   'subject': 'NDARTH433TE0',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 13, 33, 12, 695194, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds005510_sub-NDARNL587LVL_task-RestingState_eeg.set',
#   'dataset': 'ds005510',
#   'bidspath': 'ds005510/sub-NDARNL587LVL/eeg/sub-NDARNL587LVL_task-RestingState_eeg.set',
#   'subject': 'NDARNL587LVL',
#   'task': 'RestingState',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 500,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 17, 13, 33, 27, 537539, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None}]

# %%
signalstore.find({'dataset': 'ds002718'})
# Out:
# Found 18 records
# [{'schema_ref': 'eeg_signal',
#   'data_name': 'ds002718_sub-014_task-FaceRecognition_eeg.set',
#   'dataset': 'ds002718',
#   'subject': '014',
#   'task': 'FaceRecognition',
#   'session': '',
#   'run': '',
#   'modality': 'EEG',
#   'sampling_frequency': 250,
#   'version_timestamp': 0,
#   'has_file': True,
#   'time_of_save': datetime.datetime(2024, 10, 25, 14, 20, 23, 990406, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds002718_sub-012_task-FaceRecognition_eeg.set',
#   'dataset': 'ds002718',
#   'subject': '012',
#   'task': 'FaceRecognition',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 250,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2024, 10, 25, 14, 38, 37, 582636, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds002718_sub-015_task-FaceRecognition_eeg.set',
#   'dataset': 'ds002718',
#   'subject': '015',
#   'task': 'FaceRecognition',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 250,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2024, 10, 25, 14, 38, 38, 898428, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds002718_sub-008_task-FaceRecognition_eeg.set',
#   'dataset': 'ds002718',
#   'subject': '008',
#   'task': 'FaceRecognition',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 250,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2024, 10, 25, 14, 38, 40, 207469, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds002718_sub-006_task-FaceRecognition_eeg.set',
#   'dataset': 'ds002718',
#   'subject': '006',
#   'task': 'FaceRecognition',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 250,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2024, 10, 25, 14, 38, 41, 516360, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds002718_sub-013_task-FaceRecognition_eeg.set',
#   'dataset': 'ds002718',
#   'subject': '013',
#   'task': 'FaceRecognition',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 250,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2024, 10, 25, 14, 38, 42, 832414, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds002718_sub-004_task-FaceRecognition_eeg.set',
#   'dataset': 'ds002718',
#   'subject': '004',
#   'task': 'FaceRecognition',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 250,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2024, 10, 25, 14, 38, 44, 132210, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds002718_sub-016_task-FaceRecognition_eeg.set',
#   'dataset': 'ds002718',
#   'subject': '016',
#   'task': 'FaceRecognition',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 250,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2024, 10, 25, 14, 38, 45, 435612, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds002718_sub-002_task-FaceRecognition_eeg.set',
#   'dataset': 'ds002718',
#   'subject': '002',
#   'task': 'FaceRecognition',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 250,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2024, 10, 25, 14, 38, 46, 736571, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds002718_sub-018_task-FaceRecognition_eeg.set',
#   'dataset': 'ds002718',
#   'subject': '018',
#   'task': 'FaceRecognition',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 250,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2024, 10, 25, 14, 38, 48, 52476, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds002718_sub-007_task-FaceRecognition_eeg.set',
#   'dataset': 'ds002718',
#   'subject': '007',
#   'task': 'FaceRecognition',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 250,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2024, 10, 25, 14, 38, 49, 350637, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds002718_sub-010_task-FaceRecognition_eeg.set',
#   'dataset': 'ds002718',
#   'subject': '010',
#   'task': 'FaceRecognition',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 250,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2024, 10, 25, 14, 38, 50, 655335, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds002718_sub-017_task-FaceRecognition_eeg.set',
#   'dataset': 'ds002718',
#   'subject': '017',
#   'task': 'FaceRecognition',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 250,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2024, 10, 25, 14, 38, 51, 959209, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds002718_sub-003_task-FaceRecognition_eeg.set',
#   'dataset': 'ds002718',
#   'subject': '003',
#   'task': 'FaceRecognition',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 250,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2024, 10, 25, 14, 38, 53, 265755, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds002718_sub-011_task-FaceRecognition_eeg.set',
#   'dataset': 'ds002718',
#   'subject': '011',
#   'task': 'FaceRecognition',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 250,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2024, 10, 25, 14, 38, 54, 573328, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds002718_sub-005_task-FaceRecognition_eeg.set',
#   'dataset': 'ds002718',
#   'subject': '005',
#   'task': 'FaceRecognition',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 250,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2024, 10, 25, 14, 38, 55, 888644, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds002718_sub-009_task-FaceRecognition_eeg.set',
#   'dataset': 'ds002718',
#   'subject': '009',
#   'task': 'FaceRecognition',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 250,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2024, 10, 25, 14, 38, 57, 192382, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None},
#  {'schema_ref': 'eeg_signal',
#   'data_name': 'ds002718_sub-019_task-FaceRecognition_eeg.set',
#   'dataset': 'ds002718',
#   'subject': '019',
#   'task': 'FaceRecognition',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 250,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2024, 10, 25, 14, 38, 58, 516998, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None}]

# %%
data = signalstore.get({'dataset': 'ds002718'})
# Out:
# Found 18 records

# %%
data
# Out:
# [<xarray.DataArray 'eeg_signal__ds002718_sub-014_task-FaceRecognition_eeg.set' (
#                                                                                 channel: 74,
#                                                                                 time: 742500)> Size: 440MB
#  [54945000 values with dtype=float64]
#  Coordinates:
#    * channel  (channel) object 592B 'EEG001' 'EEG002' ... 'EEG073' 'EEG074'
#    * time     (time) float64 6MB 0.0 0.004 0.008 ... 2.97e+03 2.97e+03 2.97e+03
#  Attributes:
#      data_name:           ds002718_sub-014_task-FaceRecognition_eeg.set
#      dataset:             ds002718
#      has_file:            True
#      modality:            EEG
#      run:
#      sampling_frequency:  250
#      schema_ref:          eeg_signal
#      session:
#      subject:             14
#      task:                FaceRecognition
#      version_timestamp:   0]

# %%
data = signalstore.get({'dataset': 'ds002718'})
# Out:
# Found 18 records
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 32 concurrent workers.
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: Estimated head radius (11.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: Data will be preloaded. preload=False or a string preload is not supported when the data is stored in the .set file
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: Data will be preloaded. preload=False or a string preload is not supported when the data is stored in the .set file
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: Estimated head radius (11.8 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: Data will be preloaded. preload=False or a string preload is not supported when the data is stored in the .set file
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: Data will be preloaded. preload=False or a string preload is not supported when the data is stored in the .set file
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: Data will be preloaded. preload=False or a string preload is not supported when the data is stored in the .set file
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: Data will be preloaded. preload=False or a string preload is not supported when the data is stored in the .set file
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: Data will be preloaded. preload=False or a string preload is not supported when the data is stored in the .set file
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: Data will be preloaded. preload=False or a string preload is not supported when the data is stored in the .set file
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: Data will be preloaded. preload=False or a string preload is not supported when the data is stored in the .set file
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: Data will be preloaded. preload=False or a string preload is not supported when the data is stored in the .set file
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: Data will be preloaded. preload=False or a string preload is not supported when the data is stored in the .set file
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: Estimated head radius (11.0 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: Data will be preloaded. preload=False or a string preload is not supported when the data is stored in the .set file
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#
# [Parallel(n_jobs=-1)]: Done  12 out of  18 | elapsed:  1.6min remaining:   46.6s
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: Data will be preloaded. preload=False or a string preload is not supported when the data is stored in the .set file
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: Data will be preloaded. preload=False or a string preload is not supported when the data is stored in the .set file
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: Estimated head radius (11.0 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: Data will be preloaded. preload=False or a string preload is not supported when the data is stored in the .set file
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: Data will be preloaded. preload=False or a string preload is not supported when the data is stored in the .set file
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: Data will be preloaded. preload=False or a string preload is not supported when the data is stored in the .set file
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: Data will be preloaded. preload=False or a string preload is not supported when the data is stored in the .set file
#
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#
# [Parallel(n_jobs=-1)]: Done  18 out of  18 | elapsed:  2.7min finished

# %%
data = signalstore.get({'data_name': 'ds002718_sub-014_task-FaceRecognition_eeg.set'})
# Out:
# Found 1 records
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 32 concurrent workers.
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: Data will be preloaded. preload=False or a string preload is not supported when the data is stored in the .set file
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/eegdash/signalstore_data_utils.py:154: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   EEG = mne.io.read_raw_eeglab(bids_file)

# %%
data
# Out:
# [<xarray.DataArray (channel: 74, time: 742500)> Size: 440MB
#  array([[ 2.58396435e-05,  4.94110756e-05,  6.28083305e-05, ...,
#          -3.53054786e-06,  5.40610695e-06,  1.81465645e-05],
#         [ 3.97048140e-06,  1.96320801e-05,  3.37171974e-05, ...,
#          -3.26272926e-05, -1.94661694e-05,  6.31995487e-06],
#         [ 4.26879120e-05,  8.60365448e-05,  7.25059967e-05, ...,
#           1.36346607e-05,  1.26173744e-05,  2.29094810e-05],
#         ...,
#         [ 5.08860207e-05,  7.57858047e-05,  9.38854523e-05, ...,
#           3.51231813e-06,  1.54757624e-05,  2.55174599e-05],
#         [ 2.23012142e-05,  5.45197754e-05,  8.15926514e-05, ...,
#          -7.48255615e-05, -5.43508720e-05, -4.45251999e-05],
#         [ 1.99299202e-05,  4.16302872e-05,  5.81165123e-05, ...,
#          -6.04362667e-07,  5.20987988e-06,  1.41103592e-05]],
#        shape=(74, 742500))
#  Coordinates:
#    * time     (time) float64 6MB 0.0 0.004 0.008 ... 2.97e+03 2.97e+03 2.97e+03
#    * channel  (channel) <U6 2kB 'EEG001' 'EEG002' 'EEG003' ... 'EEG073' 'EEG074']

# %%
data = signalstore.get({'dataset': 'ds002718'})
# Out:
# Found 18 records
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 32 concurrent workers.
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: Data will be preloaded. preload=False or a string preload is not supported when the data is stored in the .set file
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   EEG = mne.io.read_raw_eeglab(bids_file)
# data shape: (74, 738750)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: Data will be preloaded. preload=False or a string preload is not supported when the data is stored in the .set file
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: Data will be preloaded. preload=False or a string preload is not supported when the data is stored in the .set file
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   EEG = mne.io.read_raw_eeglab(bids_file)
# data shape: (74, 740000)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   EEG = mne.io.read_raw_eeglab(bids_file)
# data shape: (74, 749000)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: Data will be preloaded. preload=False or a string preload is not supported when the data is stored in the .set file
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: Data will be preloaded. preload=False or a string preload is not supported when the data is stored in the .set file
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   EEG = mne.io.read_raw_eeglab(bids_file)
# data shape: (74, 741750)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: Data will be preloaded. preload=False or a string preload is not supported when the data is stored in the .set file
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   EEG = mne.io.read_raw_eeglab(bids_file)
# data shape: (74, 747750)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   EEG = mne.io.read_raw_eeglab(bids_file)
# data shape: (74, 747000)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: Estimated head radius (11.0 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: Data will be preloaded. preload=False or a string preload is not supported when the data is stored in the .set file
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   EEG = mne.io.read_raw_eeglab(bids_file)
# data shape: (74, 739500)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: Data will be preloaded. preload=False or a string preload is not supported when the data is stored in the .set file
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   EEG = mne.io.read_raw_eeglab(bids_file)
# data shape: (74, 742500)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: Data will be preloaded. preload=False or a string preload is not supported when the data is stored in the .set file
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   EEG = mne.io.read_raw_eeglab(bids_file)
# data shape: (74, 738750)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: Data will be preloaded. preload=False or a string preload is not supported when the data is stored in the .set file
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   EEG = mne.io.read_raw_eeglab(bids_file)
# data shape: (74, 736750)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: Data will be preloaded. preload=False or a string preload is not supported when the data is stored in the .set file
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   EEG = mne.io.read_raw_eeglab(bids_file)
# data shape: (74, 736500)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: Estimated head radius (11.0 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: Data will be preloaded. preload=False or a string preload is not supported when the data is stored in the .set file
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   EEG = mne.io.read_raw_eeglab(bids_file)
# data shape: (74, 743000)
# [Parallel(n_jobs=-1)]: Done  12 out of  18 | elapsed:  1.5min remaining:   45.3s
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: Data will be preloaded. preload=False or a string preload is not supported when the data is stored in the .set file
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   EEG = mne.io.read_raw_eeglab(bids_file)
# data shape: (74, 749000)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: Data will be preloaded. preload=False or a string preload is not supported when the data is stored in the .set file
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   EEG = mne.io.read_raw_eeglab(bids_file)
# data shape: (74, 742500)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: Estimated head radius (11.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: Data will be preloaded. preload=False or a string preload is not supported when the data is stored in the .set file
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   EEG = mne.io.read_raw_eeglab(bids_file)
# data shape: (74, 738250)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: Data will be preloaded. preload=False or a string preload is not supported when the data is stored in the .set file
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   EEG = mne.io.read_raw_eeglab(bids_file)
# data shape: (74, 744000)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: Estimated head radius (11.8 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: Data will be preloaded. preload=False or a string preload is not supported when the data is stored in the .set file
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   EEG = mne.io.read_raw_eeglab(bids_file)
# data shape: (74, 743250)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: Data will be preloaded. preload=False or a string preload is not supported when the data is stored in the .set file
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:154: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   EEG = mne.io.read_raw_eeglab(bids_file)
# data shape: (74, 741500)
# [Parallel(n_jobs=-1)]: Done  18 out of  18 | elapsed:  2.0min finished

# %%
len(data)
# Out:
# 18

# %%
signalstore.find({'data_name': 'ds002718_sub-014_task-FaceRecognition_eeg.set'})
# Out:
# Found 1 records
# [{'schema_ref': 'eeg_signal',
#   'data_name': 'ds002718_sub-014_task-FaceRecognition_eeg.set',
#   'dataset': 'ds002718',
#   'bidspath': 'ds002718/sub-014/eeg/sub-014_task-FaceRecognition_eeg.set',
#   'subject': '014',
#   'task': 'FaceRecognition',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 250,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': datetime.datetime(2025, 1, 7, 23, 21, 37, 535248, tzinfo=datetime.timezone.utc),
#   'time_of_removal': None}]

# %%
data = signalstore.get({'data_name': 'ds002718_sub-014_task-FaceRecognition_eeg.set'})
# Out:
# Found 1 records
# openneuro path openneuro.org/ds002718/sub-014/eeg/sub-014_task-FaceRecognition_eeg.set
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:144: RuntimeWarning: Unknown types found, setting as type EEG:
# ekg: ['EEG063', 'EEG064']
# heog: ['EEG061']
# veog: ['EEG062']
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:144: RuntimeWarning: Data will be preloaded. preload=False or a string preload is not supported when the data is stored in the .set file
#   EEG = mne.io.read_raw_eeglab(bids_file)
# /home/dung/Documents/EEG-Dash-Data/tests/../eegdash/signalstore_data_utils.py:144: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   EEG = mne.io.read_raw_eeglab(bids_file)
# data shape: (74, 742500)
