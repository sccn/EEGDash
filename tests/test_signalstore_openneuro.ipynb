# %%
# To be able to make edits to repo without having to restart notebook
# %load_ext autoreload
# %autoreload 2
# import sys 
# sys.path.append('..')
from eegdash.data_utils import BIDSDataset
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# To be able to make edits to repo without having to restart notebook
# %load_ext autoreload
# %autoreload 2
from eegdash import EEGDash
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
eegdashdata = EEGDash(is_public=False)
eegdashdata.add({'dataset':'test', #           'data_name': 'test', 
          'bidspath':'testpath', 
          'subject':'test', 
          'session':'test', 
          'task':'test', 
          'sampling_frequency': 250.0,
          'modality': 'EEG',
          'nchans':64,
          'ntimes':74000,
          'channel_types': ['EEG']*64,
          'channel_names': [f'EEG{i}' for i in range(1,65)]
        })
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
eegdashdata = EEGDash()
eegdashdata.find({'data_name': 'ds002718_sub-014_task-FaceRecognition_eeg.set'})
# Out:
# [{'_id': ObjectId('677db70295291b67a99cada1'),
#   'schema_ref': 'eeg_signal',
#   'data_name': 'ds002718_sub-014_task-FaceRecognition_eeg.set',
#   'dataset': 'ds002718',
#   'bidspath': 'ds002718/sub-014/eeg/sub-014_task-FaceRecognition_eeg.set',
#   'subject': '014',
#   'task': 'FaceRecognition',
#   'session': '',
#   'run': '',
#   'sampling_frequency': 250,
#   'modality': 'EEG',
#   'has_file': True,
#   'version_timestamp': 0,
#   'time_of_save': 1738946443346607,
#   'time_of_removal': None,
#   'nchans': 74,
#   'ntimes': 742500,
#   'channel_types': ['EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'HEOG',
#    'VEOG',
#    'ECG',
#    'ECG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG',
#    'EEG'],
#   'channel_names': ['EEG001',
#    'EEG002',
#    'EEG003',
#    'EEG004',
#    'EEG005',
#    'EEG006',
#    'EEG007',
#    'EEG008',
#    'EEG009',
#    'EEG010',
#    'EEG011',
#    'EEG012',
#    'EEG013',
#    'EEG014',
#    'EEG015',
#    'EEG016',
#    'EEG017',
#    'EEG018',
#    'EEG019',
#    'EEG020',
#    'EEG021',
#    'EEG022',
#    'EEG023',
#    'EEG024',
#    'EEG025',
#    'EEG026',
#    'EEG027',
#    'EEG028',
#    'EEG029',
#    'EEG030',
#    'EEG031',
#    'EEG032',
#    'EEG033',
#    'EEG034',
#    'EEG035',
#    'EEG036',
#    'EEG037',
#    'EEG038',
#    'EEG039',
#    'EEG040',
#    'EEG041',
#    'EEG042',
#    'EEG043',
#    'EEG044',
#    'EEG045',
#    'EEG046',
#    'EEG047',
#    'EEG048',
#    'EEG049',
#    'EEG050',
#    'EEG051',
#    'EEG052',
#    'EEG053',
#    'EEG054',
#    'EEG055',
#    'EEG056',
#    'EEG057',
#    'EEG058',
#    'EEG059',
#    'EEG060',
#    'EEG061',
#    'EEG062',
#    'EEG063',
#    'EEG064',
#    'EEG065',
#    'EEG066',
#    'EEG067',
#    'EEG068',
#    'EEG069',
#    'EEG070',
#    'EEG071',
#    'EEG072',
#    'EEG073',
#    'EEG074']}]

# %%
eegdashdata = EEGDash(is_public=False)
eegdashdata.update({'dataset':'test', #           'data_name': 'test', 
        'data_name': 'test',
        'bidspath':'testpath', 
        'subject':'test', 
        'session':'test', 
        'task':'test', 
        'sampling_frequency': 500.0,
        'modality': 'EEG',
        'nchans':64,
        'ntimes':74000,
    })
